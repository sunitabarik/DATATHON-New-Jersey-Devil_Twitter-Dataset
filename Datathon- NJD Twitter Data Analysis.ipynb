# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('NJD_TWITTER_DATATHON_clean.xlsx', index_col=None, header=[0])
df.head(3)
# Out:
#   CONTENT_TYPE       DATE           TIMESTAMP   BRAND  IMPACT  ENGAGEMENT  \
# 0        tweet 2022-01-31 2022-01-31 09:51:47  172721  0.4970         151
# 1        tweet 2022-01-31 2022-01-31 10:18:00  172721  1.8650         632
# 2        tweet 2022-01-31 2022-01-31 12:07:05  172721  0.6897         231
#
#   CONTENT_HASHTAGS CHANNEL_INFO_CHANNEL CHANNEL_INFO_TYPE  \
# 0              NaN              twitter             photo
# 1             NEWS              twitter              link
# 2              NaN              twitter             photo
#
#                                         CONTENT_TEXT  \
# 0  Lets close this trip out on a high.\n\nâ°: 7:...
# 1  #NEWS: Due to the recent passing of his father...
# 2  Putting in work up north. https://t.co/yoYZGN3xeO
#
#                                   CONTENT_LINK_TITLE  CONTENT_RETWEET_COUNT  \
# 0                                                NaN                     10
# 1  Ruff to Miss Two Games with Passing of his Fat...                     61
# 2                                                NaN                     10
#
#    CONTENT_FAVORITE_COUNT GAMERESULTS
# 0                     141        LOSS
# 1                     571        LOSS
# 2                     221        LOSS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17270 entries, 0 to 17269
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CONTENT_TYPE            17270 non-null  object
#  1   DATE                    17270 non-null  datetime64[ns]
#  2   TIMESTAMP               17270 non-null  datetime64[ns]
#  3   BRAND                   17270 non-null  int64
#  4   IMPACT                  17270 non-null  float64
#  5   ENGAGEMENT              17270 non-null  int64
#  6   CONTENT_HASHTAGS        10174 non-null  object
#  7   CHANNEL_INFO_CHANNEL    17270 non-null  object
#  8   CHANNEL_INFO_TYPE       17270 non-null  object
#  9   CONTENT_TEXT            15902 non-null  object
#  10  CONTENT_LINK_TITLE      4380 non-null   object
#  11  CONTENT_RETWEET_COUNT   17270 non-null  int64
#  12  CONTENT_FAVORITE_COUNT  17270 non-null  int64
#  13  GAMERESULTS             17270 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(7)
# memory usage: 1.8+ MB

# %%
#drop : single value
df.CONTENT_TYPE.value_counts()
# Out:
# tweet    17270
# Name: CONTENT_TYPE, dtype: int64

# %%
##drop : single value
df.BRAND.value_counts(dropna=False,normalize = True)
# Out:
# 172721    1.0
# Name: BRAND, dtype: float64

# %%
df.IMPACT.describe()
# Out:
# count    17270.000000
# mean         0.893296
# std          1.859127
# min          0.000000
# 25%          0.236400
# 50%          0.448300
# 75%          0.927400
# max        107.860900
# Name: IMPACT, dtype: float64

# %%
mydata = pd.DataFrame()
mydata["bins"] = pd.cut(df.IMPACT, [0,2,3,5,10,108])
mydata["bins"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.IMPACT.describe()
# Out:
# count    17270.000000
# mean         0.893296
# std          1.859127
# min          0.000000
# 25%          0.236400
# 50%          0.448300
# 75%          0.927400
# max        107.860900
# Name: IMPACT, dtype: float64

# %%
df.ENGAGEMENT.describe()
# Out:
# count    17270.000000
# mean       276.467169
# std        605.467163
# min          0.000000
# 25%         64.000000
# 50%        127.000000
# 75%        279.000000
# max      27010.000000
# Name: ENGAGEMENT, dtype: float64

# %%
mydata["bins"] = pd.cut(df.ENGAGEMENT, [0,100,200,300,400,500,600,700,27011])
mydata["bins"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17270 entries, 0 to 17269
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CONTENT_TYPE            17270 non-null  object
#  1   DATE                    17270 non-null  datetime64[ns]
#  2   TIMESTAMP               17270 non-null  datetime64[ns]
#  3   BRAND                   17270 non-null  int64
#  4   IMPACT                  17270 non-null  float64
#  5   ENGAGEMENT              17270 non-null  int64
#  6   CONTENT_HASHTAGS        10174 non-null  object
#  7   CHANNEL_INFO_CHANNEL    17270 non-null  object
#  8   CHANNEL_INFO_TYPE       17270 non-null  object
#  9   CONTENT_TEXT            15902 non-null  object
#  10  CONTENT_LINK_TITLE      4380 non-null   object
#  11  CONTENT_RETWEET_COUNT   17270 non-null  int64
#  12  CONTENT_FAVORITE_COUNT  17270 non-null  int64
#  13  GAMERESULTS             17270 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(4), object(7)
# memory usage: 1.8+ MB

# %%
#41 % misisng values
df.CONTENT_HASHTAGS.value_counts(dropna=False,normalize = True)
# Out:
# NaN                                              0.410886
# NJDevils                                         0.155646
# WeAreTheOnes NJDevils                            0.054951
# WeAreOne NJDevils                                0.018703
# NEWS                                             0.009612
#                                                    ...
# NJDevils OurTime RBNY                            0.000058
# ALLINCHALLENGE ALLIN                             0.000058
# WorldPhotographyDay NJDevils                     0.000058
# BlackHockeyHistory BlackHistoryMonth NJDevils    0.000058
# InTheMix NJDevils SweepTheDeck                   0.000058
# Name: CONTENT_HASHTAGS, Length: 1314, dtype: float64

# %%
#drop
df.CHANNEL_INFO_CHANNEL.value_counts(dropna=False,normalize = True)
# Out:
# twitter    1.0
# Name: CHANNEL_INFO_CHANNEL, dtype: float64

# %%
df.CHANNEL_INFO_TYPE.value_counts(dropna=False,normalize = True)
# Out:
# photo             0.663289
# link              0.198089
# text only         0.099710
# photo and link    0.038911
# Name: CHANNEL_INFO_TYPE, dtype: float64

# %%
df.CONTENT_LINK_TITLE.value_counts(dropna=False,normalize = True)
# Out:
# NaN                                                                 0.746381
# New Jersey Devils on Twitter                                        0.031268
# YouTube                                                             0.007354
# Single-Game Tickets / Theme Nights / Promotions                     0.004517
# Health Care Heroes | RWJBarnabas Health                             0.004169
#                                                                       ...
# Moynihan Working to Round Out his Game | PROSPECT WATCH             0.000058
# Devils look to remain undefeated against Stars                      0.000058
# Grier, Salvador excited to coach all-minority team at tournament    0.000058
# Mercer | PRACTICE RAW 1.20.22                                       0.000058
# Saint Patrick on Twitter                                            0.000058
# Name: CONTENT_LINK_TITLE, Length: 2448, dtype: float64

# %%
df.CONTENT_HASHTAGS.value_counts(dropna=False,normalize = True)
# Out:
# NaN                                              0.410886
# NJDevils                                         0.155646
# WeAreTheOnes NJDevils                            0.054951
# WeAreOne NJDevils                                0.018703
# NEWS                                             0.009612
#                                                    ...
# NJDevils OurTime RBNY                            0.000058
# ALLINCHALLENGE ALLIN                             0.000058
# WorldPhotographyDay NJDevils                     0.000058
# BlackHockeyHistory BlackHistoryMonth NJDevils    0.000058
# InTheMix NJDevils SweepTheDeck                   0.000058
# Name: CONTENT_HASHTAGS, Length: 1314, dtype: float64

# %%
df.CONTENT_TEXT.value_counts(dropna=False,normalize = True)
# Out:
# NaN                                                                                                                                                                                                                                                                                0.079213
# 2-0, them.                                                                                                                                                                                                                                                                         0.000463
# You good?                                                                                                                                                                                                                                                                          0.000232
# Tie game.                                                                                                                                                                                                                                                                          0.000232
# ðŸš¨Trivia TuesdayðŸš¨\n\nSpeed &amp; accuracy are key. Answer 10 questions. The faster you answer correctly, the more points you will get.\n\nThe player with the most points after 10 questions wins! Watch our feeds at 3PM for a link to play...\n\nhttps://t.co/91HXVYdXXV    0.000174
#                                                                                                                                                                                                                                                                                      ...
# RT for Palmieri or LIKE for Seversons goal in this weeks @jag_onept Play of the Week! https://t.co/v5WTkiNz9d                                                                                                                                                                      0.000058
# Back to even strength! https://t.co/bqmkfXZcyl                                                                                                                                                                                                                                     0.000058
# You can vote at https://t.co/2DKRdTTd85 beginning Wednesday, Jan. 1 at 12 p.m. ET through Jan. 10.\n\n#WeAreTheOnes | #VoteNico https://t.co/aQqEhBEqwo                                                                                                                            0.000058
# Its #NJDevils Pick â€˜Em presented by @WilliamHillUS!\n\nWho is the only person to serve as head coach for both the New Jersey Devils and Pittsburgh Penguins?                                                                                                                     0.000058
# âœ”ï¸ Getting loose and warmed up\nâœ”ï¸ Using foam rollers\nâœ”ï¸ Doing lunges, quad stretches, hip flexers\n\nAll this and more are part of 'What It Takes' in Andy Greene's routine to stay prepared for game days. @jag_onept https://t.co/br9XTAorWs                       0.000058
# Name: CONTENT_TEXT, Length: 15819, dtype: float64

# %%
mydata["bins"] = pd.cut(df.CONTENT_RETWEET_COUNT, [0,10,20,30,50,100,200,300,400,500])
mydata["bins"].value_counts().plot.bar()
#        17270 non-null  int64         
#  12    17270 non-null  int64
# Out:
# <AxesSubplot:>

# %%
df.CONTENT_FAVORITE_COUNT.describe()
# Out:
# count    17270.000000
# mean       246.746323
# std        533.188265
# min          0.000000
# 25%         58.000000
# 50%        115.000000
# 75%        252.000000
# max      23602.000000
# Name: CONTENT_FAVORITE_COUNT, dtype: float64

# %%
mydata["bins"] = pd.cut(df.CONTENT_FAVORITE_COUNT, [0,50,100,200,300,400,500,23603])
mydata["bins"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.GAMERESULTS.value_counts()
# Out:
# NO GAME    11640
# LOSS        3370
# WON         2260
# Name: GAMERESULTS, dtype: int64

# %%
df.nunique()
# Out:
# CONTENT_TYPE                  1
# DATE                       1152
# TIMESTAMP                 17230
# BRAND                         1
# IMPACT                    10042
# ENGAGEMENT                 1583
# CONTENT_HASHTAGS           1313
# CHANNEL_INFO_CHANNEL          1
# CHANNEL_INFO_TYPE             4
# CONTENT_TEXT              15818
# CONTENT_LINK_TITLE         2447
# CONTENT_RETWEET_COUNT       426
# CONTENT_FAVORITE_COUNT     1470
# GAMERESULTS                   3
# dtype: int64

# %%
del df['CONTENT_TYPE']  
del df['BRAND']
del df['CHANNEL_INFO_CHANNEL']

# %%
df.nunique()
# Out:
# DATE                       1152
# TIMESTAMP                 17230
# IMPACT                    10042
# ENGAGEMENT                 1583
# CONTENT_HASHTAGS           1313
# CHANNEL_INFO_TYPE             4
# CONTENT_TEXT              15818
# CONTENT_LINK_TITLE         2447
# CONTENT_RETWEET_COUNT       426
# CONTENT_FAVORITE_COUNT     1470
# GAMERESULTS                   3
# dtype: int64

# %%
df.head(3)
# Out:
#         DATE           TIMESTAMP  IMPACT  ENGAGEMENT CONTENT_HASHTAGS  \
# 0 2022-01-31 2022-01-31 09:51:47  0.4970         151              NaN
# 1 2022-01-31 2022-01-31 10:18:00  1.8650         632             NEWS
# 2 2022-01-31 2022-01-31 12:07:05  0.6897         231              NaN
#
#   CHANNEL_INFO_TYPE                                       CONTENT_TEXT  \
# 0             photo  Lets close this trip out on a high.\n\nâ°: 7:...
# 1              link  #NEWS: Due to the recent passing of his father...
# 2             photo  Putting in work up north. https://t.co/yoYZGN3xeO
#
#                                   CONTENT_LINK_TITLE  CONTENT_RETWEET_COUNT  \
# 0                                                NaN                     10
# 1  Ruff to Miss Two Games with Passing of his Fat...                     61
# 2                                                NaN                     10
#
#    CONTENT_FAVORITE_COUNT GAMERESULTS
# 0                     141        LOSS
# 1                     571        LOSS
# 2                     221        LOSS

# %%
from sklearn.feature_extraction.text import CountVectorizer

df_rna = df[df['CONTENT_LINK_TITLE'].notna()]
cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(df_rna.CONTENT_LINK_TITLE)

sum_words = words.sum(axis=0)

words_freq = [(word, sum_words[0, i]) for word, i in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)

frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

frequency.head(30).plot(x='word', y='freq', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring Words - Top 30")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring Words - Top 30')

# %%
#pip install wordcloud

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(background_color = 'white', width = 1000, height = 1000).generate_from_frequencies(dict(words_freq))

plt.figure(figsize=(10,8))
plt.imshow(wordcloud)
plt.title("WordCloud - Vocabulary from CONTENT_LINK_TITLE", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'WordCloud - Vocabulary from CONTENT_LINK_TITLE')

# %%
normal_words =' '.join([text for text in df_rna['CONTENT_LINK_TITLE'][df_rna['GAMERESULTS'] == 'WON']])

wordcloud = WordCloud(width=800, height=500, random_state = 0, max_font_size = 110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('CONTENT_LINK_TITLE - GAMERESULTS:WON')
plt.show()

# %%
df['clean_CONTENT_TEXT'] = df['CONTENT_TEXT'].astype(str).apply(lambda x: x.encode('ascii', 'ignore').decode('ascii'))

# %%
import nltk
from sklearn.feature_extraction.text import CountVectorizer

df_rna = df[df['clean_CONTENT_TEXT'].notna()]
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['https','njdevils','nan']
stopwords.extend(newStopWords)


cv = CountVectorizer(stop_words = stopwords)
words = cv.fit_transform(df_rna.clean_CONTENT_TEXT)

sum_words = words.sum(axis=0)

words_freq = [(word, sum_words[0, i]) for word, i in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)

frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

frequency.head(30).plot(x='word', y='freq', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring Words - Top 30")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring Words - Top 30')

# %%
wordcloud = WordCloud(background_color = 'white', width = 1000, height = 1000).generate_from_frequencies(dict(words_freq))

plt.figure(figsize=(10,8))
plt.imshow(wordcloud)
plt.title("WordCloud - Vocabulary from CONTENT_LINK_TITLE", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'WordCloud - Vocabulary from CONTENT_LINK_TITLE')

# %%
normal_words =' '.join([text for text in df_rna['clean_CONTENT_TEXT'][df_rna['GAMERESULTS'] == 'WON']])

wordcloud = WordCloud(width=800, height=500, random_state = 0, max_font_size = 110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('clean_CONTENT_TEXT - clean_CONTENT_TEXT:WON')
plt.show()

# %%
normal_words =' '.join([text for text in df_rna['clean_CONTENT_TEXT'][df_rna['GAMERESULTS'] == 'LOSS']])

wordcloud = WordCloud(width=800, height=500, random_state = 0, max_font_size = 110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('clean_CONTENT_TEXT - clean_CONTENT_TEXT:LOSS')
plt.show()

# %%
normal_words =' '.join([text for text in df_rna['clean_CONTENT_TEXT'][df_rna['GAMERESULTS'] == 'NO GAME']])

wordcloud = WordCloud(width=800, height=500, random_state = 0, max_font_size = 110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('clean_CONTENT_TEXT - clean_CONTENT_TEXT:LOSS')
plt.show()

# %%
#pip install plotly

# %%
# Imports
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px
# Product Scores
fig = px.histogram(df, x="IMPACT")
fig.update_traces(marker_color="turquoise",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='IMPACT')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="ffeb3ed8-b39a-4232-830e-2ffe44f83aeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffeb3ed8-b39a-4232-830e-2ffe44f83aeb")) {                    Plotly.newPlot(                        "ffeb3ed8-b39a-4232-830e-2ffe44f83aeb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"IMPACT=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"turquoise","pattern":{"shape":""},"line":{"color":"rgb(8,48,107)","width":1.5}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0.497,1.865,0.6897,0.1824,0.0132,0.389,0.2618,0.2519,0.2155,0.2584,0.1279,0.6461,0.6365,0.454,0.1853,0.2141,0.2047,0.1694,0.2828,0.1885,0.2111,0.3425,0.2401,0.4796,0.2363,0.8502,0.2657,0.5141,0.1451,0.6277,0.9821,0.1139,0.5935,1.3311,0.2461,0.461,0.2578,0.2842,0.1328,1.8757,1.5704,0.51,0.1702,0.1764,0.3963,0.2832,0.6039,0.1481,0.4505,0.189,0.2257,0.2431,0.1418,0.5161,0.211,0.9252,0.8887,0.1386,0.9099,0.1183,2.2459,0.2222,0.1586,0.5087,0.1305,0.2315,0.4162,0.1629,0.526,0.675,0.6913,0.2783,0.2627,0.916,0.0157,0.1656,0.2751,0.6615,0.1566,0.5602,0.6504,0.4718,0.6341,0.0718,0.0878,0.525,0.1935,0.5401,0.1374,0.2784,0.2563,2.9747,1.0632,0.175,0.1561,0.1936,0.2474,0.1691,2.7068,0.1998,0.4623,0.1298,0.7137,1.1772,0.2543,0.38,0.2415,1.3671,2.488,0.2657,1.5601,1.5671,0.0806,1.3189,0.2047,0.263,0.1025,0.2019,0.3264,1.1128,6.3755,1.0407,0.18,0.6961,1.4942,2.5536,0.1635,0.1572,0.2389,0.3187,1.3974,2.7787,0.2531,0.1117,0.265,1.2643,0.4954,2.6657,0.1616,0.9327,13.7847,1.716,1.839,0.2357,0.5398,0.7299,0.7524,0.575,0.3391,0.4748,1.4765,2.4839,0.8578,0.2495,1.0239,0.802,0.1954,0.6535,0.1855,1.1604,0.1149,1.5707,1.5335,0.6837,0.1478,0.8428,2.2947,0.6117,0.275,1.1535,0.2116,0.192,0.6566,15.0019,1.1662,0.4837,0.3026,0.304,1.2662,0.7096,0.5778,0.7324,0.1203,1.159,0.3318,3.3102,0.196,0.5981,1.5848,0.859,0.5855,0.1591,1.2565,1.255,0.2772,0.2471,0.6461,0.6823,1.8919,1.1917,1.4327,3.7717,1.3538,0.1455,0.1758,1.0031,0.2874,0.3207,0.1784,0.126,3.6972,0.345,3.5681,0.1916,2.0,0.2345,0.5991,0.5748,0.9559,1.5829,0.6284,0.2542,1.9067,0.2121,0.1987,0.2883,0.1592,0.825,0.1278,0.1754,0.3277,0.1589,0.2385,0.882,0.194,0.1998,0.4813,0.8487,0.2726,0.1661,0.259,0.2882,0.2331,0.1344,0.5006,0.2271,0.1278,0.9693,1.2521,0.4285,0.7255,0.2224,0.8273,0.3398,1.5881,0.214,0.1294,1.2126,0.0523,0.214,0.3916,0.2437,0.108,0.5535,0.7081,0.2517,0.2008,0.2617,1.7251,0.2809,0.2421,0.108,0.6279,1.0824,1.298,0.265,0.4117,0.4875,0.229,0.2617,0.1501,0.0816,0.5421,0.7361,0.2977,0.7084,3.5155,1.4047,0.2858,0.3151,0.8057,0.4813,0.6883,1.4159,0.2331,0.817,0.2285,0.2416,1.0257,2.7282,1.3906,0.359,0.2988,0.735,0.2817,2.1131,0.1988,0.1884,1.3878,1.6675,0.874,1.1892,1.1392,0.1654,0.2838,0.1973,0.7397,2.1136,0.8352,0.2336,1.9732,0.2111,1.3911,0.8417,0.1792,0.26,0.9741,0.1719,0.2795,0.5229,0.1177,0.1941,2.5852,1.1531,0.703,0.1379,0.3322,0.7368,0.8124,0.2964,0.2791,2.6539,2.2024,0.8574,3.7907,1.6623,0.9245,0.4182,0.2091,0.2614,1.3142,1.8754,0.7513,4.2852,1.2795,0.2601,0.3055,0.014,0.5196,0.5607,0.511,1.1352,2.8425,0.2425,0.2911,0.2952,0.3593,0.689,0.2666,0.1696,0.8257,0.1627,0.7321,0.2561,0.8258,0.917,0.5328,2.1831,0.31,0.216,0.2676,0.6657,1.0033,3.9821,1.1541,0.9766,0.3443,0.513,0.8867,0.2352,0.6247,1.3291,1.8702,3.3525,0.8025,0.3273,0.3776,0.2604,1.2269,0.4189,0.9079,0.8308,0.5661,2.8223,0.4005,1.3994,0.2112,0.19,1.3048,2.0334,0.1682,0.2054,0.2153,0.2454,1.228,0.2084,0.8585,1.2369,0.9805,3.5258,0.3669,0.356,1.3337,0.6021,1.3008,0.2118,3.3845,0.3303,0.5795,0.306,0.8297,0.5921,0.9178,0.265,0.9935,5.7377,2.1982,0.744,0.286,0.7624,1.2265,0.351,0.7562,1.2691,0.9574,6.9884,3.0038,6.2685,0.2298,0.5228,4.5998,0.2406,0.2567,1.0988,0.2241,0.3045,0.8007,2.0355,0.1493,4.6732,0.1313,0.2455,0.3555,0.3591,0.1069, ...

# %%
import nltk
from nltk.corpus import stopwords
# Create stopword list:

stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['https','NJDevils','nan']
stopwords.extend(newStopWords)
textt = " ".join(review for review in df_rna.clean_CONTENT_TEXT)
wordcloud = WordCloud(width=800, height=500,stopwords=stopwords).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud11.png')
plt.show()

# %%
df.IMPACT.describe()
# Out:
# count    17270.000000
# mean         0.893296
# std          1.859127
# min          0.000000
# 25%          0.236400
# 50%          0.448300
# 75%          0.927400
# max        107.860900
# Name: IMPACT, dtype: float64

# %%
df.IMPACT.median()
# Out:
# 0.4483

# %%
#TAKING IMPACT ABOVE 75% AS POSITIVE
df['sentiment'] =  np.where(df['IMPACT'] >0.927400,1,0)

# %%
df['sentiment'].value_counts()
# Out:
# 0    12952
# 1     4318
# Name: sentiment, dtype: int64

# %%
# split df - positive and negative sentiment:
positive = df[df['sentiment'] == 1]
negative = df[df['sentiment'] == 0]

# %%
import nltk
from sklearn.feature_extraction.text import CountVectorizer

df_rna = df[df['clean_CONTENT_TEXT'].notna()]
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['https','njdevils','nan','co']
stopwords.extend(newStopWords)


cv = CountVectorizer(stop_words = stopwords)
words = cv.fit_transform(positive.clean_CONTENT_TEXT)

sum_words = words.sum(axis=0)

words_freq = [(word, sum_words[0, i]) for word, i in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)

frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

frequency.head(10).plot(x='word', y='freq', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring positive sentiments Words - Top 10")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring positive sentiments Words - Top 10')

# %%
from sklearn.feature_extraction.text import CountVectorizer
c_vec = CountVectorizer(stop_words=stopwords, ngram_range=(2,3))
# matrix of ngrams
ngrams = c_vec.fit_transform(positive.clean_CONTENT_TEXT)
# count frequency of ngrams
count_values = ngrams.toarray().sum(axis=0)
# list of ngrams
vocab = c_vec.vocabulary_
df_ngram = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()], reverse=True)
            ).rename(columns={0: 'frequency', 1:'bigram/trigram'})

# %%
df_ngram.head(10).plot(x='bigram/trigram', y='frequency', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring positive sentiments Words - Top 10")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring positive sentiments Words - Top 10')

# %%
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['https','NJDevils','nan','game','CO']
stopwords.extend(newStopWords)
## good and great removed because they were included in negative sentiment
pos = " ".join(review for review in positive.clean_CONTENT_TEXT)
wordcloud2 = WordCloud(stopwords=stopwords).generate(pos)
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import nltk
from sklearn.feature_extraction.text import CountVectorizer

df_rna = df[df['clean_CONTENT_TEXT'].notna()]
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['https','njdevils','nan','co']
stopwords.extend(newStopWords)


cv = CountVectorizer(stop_words = stopwords)
words = cv.fit_transform(negative.clean_CONTENT_TEXT)

sum_words = words.sum(axis=0)

words_freq = [(word, sum_words[0, i]) for word, i in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)

frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

frequency.head(10).plot(x='word', y='freq', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring Negative sentiment Words - Top 10")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring Negative sentiment Words - Top 10')

# %%
from sklearn.feature_extraction.text import CountVectorizer
c_vec = CountVectorizer(stop_words=stopwords, ngram_range=(2,3))
# matrix of ngrams
ngrams = c_vec.fit_transform(negative.clean_CONTENT_TEXT)
# count frequency of ngrams
count_values = ngrams.toarray().sum(axis=0)
# list of ngrams
vocab = c_vec.vocabulary_
df_ngram = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()], reverse=True)
            ).rename(columns={0: 'frequency', 1:'bigram/trigram'})

# %%
df_ngram.head(10).plot(x='bigram/trigram', y='frequency', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring Words for Negative sentiment- Top 10")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring Words for Negative sentiment- Top 10')

# %%
stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['https','NJDevils','nan','game','CO']
stopwords.extend(newStopWords)
## good and great removed because they were included in negative sentiment
pos = " ".join(review for review in negative.clean_CONTENT_TEXT)
wordcloud2 = WordCloud(stopwords=stopwords).generate(pos)
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df['sentiment_analysis'] = df['sentiment'].replace({0 : 'negative'})
df['sentiment_analysis'] = df['sentiment'].replace({1 : 'positive'})
fig = px.histogram(df, x="sentiment_analysis")
fig.update_traces(marker_color="indianred",marker_line_color='rgb(8,48,107)',
                  marker_line_width=1.5)
fig.update_layout(title_text='CONTENT_TEXT Sentiment')
fig.show()
# Out:
# <div>                            <div id="9a8e5b8e-0e07-40df-83a2-a0998dce3035" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a8e5b8e-0e07-40df-83a2-a0998dce3035")) {                    Plotly.newPlot(                        "9a8e5b8e-0e07-40df-83a2-a0998dce3035",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sentiment_analysis=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"indianred","pattern":{"shape":""},"line":{"color":"rgb(8,48,107)","width":1.5}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["negative","positive","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","positive","negative","negative","positive","negative","negative","negative","negative","negative","positive","positive","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","positive","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","positive","positive","negative","negative","negative","negative","negative","positive","negative","negative","negative","negative","positive","negative","negative","negative","positive","positive","negative","positive","positive","negative","positive","negative","negative","negative","negative","negative","positive","positive","positive","negative","negative","positive","positive","negative","negative","negative","negative","positive","positive","negative","negative","negative","positive","negative","positive","negative","positive","positive","positive","positive","negative","negative","negative","negative","negative","negative","negative","positive","positive","negative","negative","positive","negative","negative","negative","negative","positive","negative","positive","positive","negative","negative","negative","positive","negative","negative","positive","negative","negative","negative","positive","positive","negative","negative","negative","positive","negative","negative","negative","negative","positive","negative","positive","negative","negative","positive","negative","negative","negative","positive","positive","negative","negative","negative","negative","positive","positive","positive","positive","positive","negative","negative","positive","negative","negative","negative","negative","positive","negative","positive","negative","positive","negative","negative","negative","positive","positive","negative","negative","positive","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","positive","positive","negative","negative","negative","negative","negative","positive","negative","negative","positive","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","positive","negative","negative","negative","negative","positive","positive","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","negative","positive","positive","nega ...
